# %% [markdown]
# # Kronmueller and Barr (2007) revisited

# %%
using DataFrames,RCall,MixedModels
kb07 = DataFrame("RePsychLing::kb07");
dump(kb07)
# Out:
# Warning: New definition
#     &(DataArrays.DataArray{Bool,N},Union(Bool,AbstractArray{Bool,N})) at /home/bates/.julia/v0.4/DataArrays/src/operators.jl:547
# is ambiguous with:
#     &(AbstractArray{S,N},Range{T}) at array.jl:793.
# To fix, define
#     &(DataArrays.DataArray{Bool,N},Range{Bool})
# before the new definition.
# Warning: New definition
#     |(DataArrays.DataArray{Bool,N},Union(Bool,AbstractArray{Bool,N})) at /home/bates/.julia/v0.4/DataArrays/src/operators.jl:548
# is ambiguous with:
#     |(AbstractArray{S,N},Range{T}) at array.jl:793.
# To fix, define
#     |(DataArrays.DataArray{Bool,N},Range{Bool})
# before the new definition.
# Warning: New definition
#     $(DataArrays.DataArray{Bool,N},Union(Bool,AbstractArray{Bool,N})) at /home/bates/.julia/v0.4/DataArrays/src/operators.jl:549
# is ambiguous with:
#     $(AbstractArray{S,N},Range{T}) at array.jl:793.
# To fix, define
#     $(DataArrays.DataArray{Bool,N},Range{Bool})
# before the new definition.
# Warning: New definition
#     +(AbstractArray{Bool,N},DataArrays.DataArray{Bool,N}) at /home/bates/.julia/v0.4/DataArrays/src/operators.jl:326
# is ambiguous with:
#     +(Range{S},AbstractArray{T,N}) at array.jl:802.
# To fix, define
#     +(Range{Bool},DataArrays.DataArray{Bool,N})
# before the new definition.
# Warning: New definition
#     +(AbstractArray{T,N},DataArrays.DataArray{T,N}) at /home/bates/.julia/v0.4/DataArrays/src/operators.jl:326
# is ambiguous with:
#     +(Range{S},AbstractArray{T,N}) at array.jl:802.
# To fix, define
#     +(Range{T},DataArrays.DataArray{T,N})
# before the new definition.
# Warning: New definition
#     +(AbstractArray{Bool,N},DataArrays.AbstractDataArray{Bool,N}) at /home/bates/.julia/v0.4/DataArrays/src/operators.jl:350
# is ambiguous with:
#     +(Range{S},AbstractArray{T,N}) at array.jl:802.
# To fix, define
#     +(Range{Bool},DataArrays.AbstractDataArray{Bool,N})
# before the new definition.
# Warning: New definition
#     +(AbstractArray{T,N},DataArrays.AbstractDataArray{T,N}) at /home/bates/.julia/v0.4/DataArrays/src/operators.jl:350
# is ambiguous with:
#     +(Range{S},AbstractArray{T,N}) at array.jl:802.
# To fix, define
#     +(Range{T},DataArrays.AbstractDataArray{T,N})
# before the new definition.
# Warning: New definition
#     -(AbstractArray{Bool,N},DataArrays.DataArray{Bool,N}) at /home/bates/.julia/v0.4/DataArrays/src/operators.jl:326
# is ambiguous with:
#     -(Range{S},AbstractArray{T,N}) at array.jl:802.
# To fix, define
#     -(Range{Bool},DataArrays.DataArray{Bool,N})
# before the new definition.
# Warning: New definition
#     -(AbstractArray{T,N},DataArrays.DataArray{T,N}) at /home/bates/.julia/v0.4/DataArrays/src/operators.jl:326
# is ambiguous with:
#     -(Range{S},AbstractArray{T,N}) at array.jl:802.
# To fix, define
#     -(Range{T},DataArrays.DataArray{T,N})
# before the new definition.
# Warning: New definition
#     -(AbstractArray{Bool,N},DataArrays.AbstractDataArray{Bool,N}) at /home/bates/.julia/v0.4/DataArrays/src/operators.jl:350
# is ambiguous with:
#     -(Range{S},AbstractArray{T,N}) at array.jl:802.
# To fix, define
#     -(Range{Bool},DataArrays.AbstractDataArray{Bool,N})
# before the new definition.
# Warning: New definition
#     -(DataArrays.AbstractDataArray{T,N},AbstractArray{T,N}) at /home/bates/.julia/v0.4/DataArrays/src/operators.jl:350
# is ambiguous with:
#     -(AbstractArray{S,N},Range{T}) at array.jl:793.
# To fix, define
#     -(DataArrays.AbstractDataArray{S,N},Range{T})
# before the new definition.
# Warning: New definition
#     -(AbstractArray{T,N},DataArrays.AbstractDataArray{T,N}) at /home/bates/.julia/v0.4/DataArrays/src/operators.jl:350
# is ambiguous with:
#     -(Range{S},AbstractArray{T,N}) at array.jl:802.
# To fix, define
#     -(Range{T},DataArrays.AbstractDataArray{T,N})
# before the new definition.
# WARNING: dlopen is deprecated, use Libdl.dlopen instead.
#  in depwarn at ./deprecated.jl:40
#  in dlopen at ./deprecated.jl:12
#  in include at ./boot.jl:250
#  in include_from_node1 at ./loading.jl:129
#  in reload_path at ./loading.jl:153
#  in _require at ./loading.jl:68
#  in require at ./loading.jl:54
#  in include at ./boot.jl:250
#  in include_from_node1 at ./loading.jl:129
#  in reload_path at ./loading.jl:153
#  in _require at ./loading.jl:68
#  in require at ./loading.jl:52
#  in include_string at ./loading.jl:98
# WARNING: int32(x) is deprecated, use Int32(x) instead.
#  in depwarn at ./deprecated.jl:40
#  in int32 at ./deprecated.jl:31
#  in include at ./boot.jl:250
#  in include_from_node1 at ./loading.jl:129
#  in reload_path at ./loading.jl:153
#  in _require at ./loading.jl:68
#  in require at ./loading.jl:54
#  in include at ./boot.jl:250
#  in include_from_node1 at ./loading.jl:129
#  in reload_path at ./loading.jl:153
#  in _require at ./loading.jl:68
#  in require at ./loading.jl:52
#  in include_string at ./loading.jl:98
# WARNING: uint(x) is deprecated, use UInt(x) instead.
#  in depwarn at ./deprecated.jl:40
#  in uint at ./deprecated.jl:31
#  in version at /home/bates/.julia/v0.4/NLopt/src/NLopt.jl:390
#  in __init__ at /home/bates/.julia/v0.4/NLopt/src/NLopt.jl:37
#  in include at ./boot.jl:250
#  in include_from_node1 at ./loading.jl:129
#  in reload_path at ./loading.jl:153
#  in _require at ./loading.jl:68
#  in require at ./loading.jl:54
#  in include at ./boot.jl:250
#  in include_from_node1 at ./loading.jl:129
#  in reload_path at ./loading.jl:153
#  in _require at ./loading.jl:68
#  in require at ./loading.jl:52
#  in include_string at ./loading.jl:98
# WARNING: int(x) is deprecated, use Int(x) instead.
#  in depwarn at ./deprecated.jl:40
#  in int at ./deprecated.jl:31
#  in version at /home/bates/.julia/v0.4/NLopt/src/NLopt.jl:392
#  in __init__ at /home/bates/.julia/v0.4/NLopt/src/NLopt.jl:37
#  in include at ./boot.jl:250
#  in include_from_node1 at ./loading.jl:129
#  in reload_path at ./loading.jl:153
#  in _require at ./loading.jl:68
#  in require at ./loading.jl:54
#  in include at ./boot.jl:250
#  in include_from_node1 at ./loading.jl:129
#  in reload_path at ./loading.jl:153
#  in _require at ./loading.jl:68
#  in require at ./loading.jl:52
#  in include_string at ./loading.jl:98
# WARNING: int(x) is deprecated, use Int(x) instead.
#  in depwarn at ./deprecated.jl:40
#  in int at ./deprecated.jl:31
#  in version at /home/bates/.julia/v0.4/NLopt/src/NLopt.jl:392
#  in __init__ at /home/bates/.julia/v0.4/NLopt/src/NLopt.jl:37
#  in include at ./boot.jl:250
#  in include_from_node1 at ./loading.jl:129
#  in reload_path at ./loading.jl:153
#  in _require at ./loading.jl:68
#  in require at ./loading.jl:54
#  in include at ./boot.jl:250
#  in include_from_node1 at ./loading.jl:129
#  in reload_path at ./loading.jl:153
#  in _require at ./loading.jl:68
#  in require at ./loading.jl:52
#  in include_string at ./loading.jl:98
# WARNING: int(x) is deprecated, use Int(x) instead.
#  in depwarn at ./deprecated.jl:40
#  in int at ./deprecated.jl:31
#  in version at /home/bates/.julia/v0.4/NLopt/src/NLopt.jl:392
#  in __init__ at /home/bates/.julia/v0.4/NLopt/src/NLopt.jl:37
#  in include at ./boot.jl:250
#  in include_from_node1 at ./loading.jl:129
#  in reload_path at ./loading.jl:153
#  in _require at ./loading.jl:68
#  in require at ./loading.jl:54
#  in include at ./boot.jl:250
#  in include_from_node1 at ./loading.jl:129
#  in reload_path at ./loading.jl:153
#  in _require at ./loading.jl:68
#  in require at ./loading.jl:52
#  in include_string at ./loading.jl:98
# WARNING: int(x) is deprecated, use Int(x) instead.
#  in depwarn at ./deprecated.jl:40
#  in int at ./deprecated.jl:31
#  in length at /home/bates/.julia/v0.4/RCall/src/types.jl:270
#  in reval at /home/bates/.julia/v0.4/RCall/src/iface.jl:11
#  in reval at /home/bates/.julia/v0.4/RCall/src/iface.jl:16
#  in call at /home/bates/.julia/v0.4/RCall/src/sexp.jl:180
#  in include_string at ./loading.jl:98
# WARNING: bool(x::Number) is deprecated, use Bool(x) instead.
#  in depwarn at ./deprecated.jl:40
#  in bool at ./deprecated.jl:31
#  in reval at /home/bates/.julia/v0.4/RCall/src/iface.jl:5
#  in reval at /home/bates/.julia/v0.4/RCall/src/iface.jl:12
#  in reval at /home/bates/.julia/v0.4/RCall/src/iface.jl:16
#  in call at /home/bates/.julia/v0.4/RCall/src/sexp.jl:180
#  in include_string at ./loading.jl:98
# WARNING: int(x) is deprecated, use Int(x) instead.
#  in depwarn at ./deprecated.jl:40
#  in int at ./deprecated.jl:31
#  in length at /home/bates/.julia/v0.4/RCall/src/types.jl:270
#  in map at ./abstractarray.jl:1180
#  in call at /home/bates/.julia/v0.4/RCall/src/sexp.jl:176
#  in call at /home/bates/.julia/v0.4/RCall/src/sexp.jl:180
#  in include_string at ./loading.jl:98
# WARNING: int(x) is deprecated, use Int(x) instead.
#  in depwarn at ./deprecated.jl:40
#  in int at ./deprecated.jl:31
#  in length at /home/bates/.julia/v0.4/RCall/src/types.jl:270
#  in size at /home/bates/.julia/v0.4/RCall/src/sexp.jl:116
#  in call at /home/bates/.julia/v0.4/RCall/src/sexp.jl:150
#  in map at ./abstractarray.jl:1186
#  in call at /home/bates/.julia/v0.4/RCall/src/sexp.jl:176
#  in call at /home/bates/.julia/v0.4/RCall/src/sexp.jl:180
#  in include_string at ./loading.jl:98
# WARNING: int(x) is deprecated, use Int(x) instead.
#  in depwarn at ./deprecated.jl:40
#  in int at ./deprecated.jl:31
#  in length at /home/bates/.julia/v0.4/RCall/src/types.jl:270
#  in names at ./no file
#  in call at /home/bates/.julia/v0.4/RCall/src/sexp.jl:176
#  in call at /home/bates/.julia/v0.4/RCall/src/sexp.jl:180
#  in include_string at ./loading.jl:98
# DataFrames.DataFrame  1790 observations of 10 variables
#   subj: DataArrays.PooledDataArray{ASCIIString,UInt8,1}(1790) ASCIIString["30","30","30","30"]
#   item: DataArrays.PooledDataArray{ASCIIString,UInt8,1}(1790) ASCIIString["1","2","3","4"]
#   RTtrunc: DataArrays.DataArray{Float64,1}(1790) [2267
# WARNING: flush_cstdio is deprecated, use Libc.flush_cstdio instead.
# .0,3856.0,1567.0,1732.0]
#   S: DataArrays.DataArray{Float64,1}(1790) [1.0,-1.0,-1.0,1.0]
#   P: DataArrays.DataArray{Float64,1}(1790) [-1.0,1.0,-1.0,1.0]
#   C: DataArrays.DataArray{Float64,1}(1790) [1.0,-1.0,-1.0,-1.0]
#   SP: DataArrays.DataArray{Float64,1}(1790) [-1.0,-1.0,1.0,1.0]
#   SC: DataArrays.DataArray{Float64,1}(1790) [1.0,1.0,1.0,-1.0]
#   PC: DataArrays.DataArray{Float64,1}(1790) [-1.0,-1.0,1.0,-1.0]
#   SPC: DataArrays.DataArray{Float64,1}(1790) [-1.0,1.0,-1.0,-1.0]
#  in depwarn at ./deprecated.jl:40
#  in flush_cstdio at ./deprecated.jl:10
#  in execute_request_0x535c5df2 at /home/bates/.julia/v0.4/IJulia/src/execute_request.jl:185
#  in eventloop at /home/bates/.julia/v0.4/IJulia/src/IJulia.jl:123
#  in anonymous at ./task.jl:361
