# %% [markdown]
# # The poems data

# %%
using DataFrames,MixedModels
#poems = DataFrame("RePsychLing::poems")

# %%
poems = MixedModels.rdata("poems")
# Out:
# 275996x31 DataFrame
# | Row    | ReadingTime | Subject   | Sex | Age  | NPoems | MultipleChoiceRT |
# |--------|-------------|-----------|-----|------|--------|------------------|
# | 1      | 340         | "Subj281" | "f" | 22.0 | 58.0   | 9704             |
# | 2      | 344         | "Subj290" | "f" | 30.0 | 17.0   | 25469            |
# | 3      | 453         | "Subj119" | "m" | 21.0 | 17.0   | 23015            |
# | 4      | 290         | "Subj112" | "m" | 23.0 | 5.0    | 7110             |
# | 5      | 343         | "Subj294" | "m" | 21.0 | 5.0    | 12547            |
# | 6      | 296         | "Subj52"  | "f" | 22.0 | 17.0   | 15515            |
# | 7      | 321         | "Subj118" | "m" | 48.0 | 17.0   | 9313             |
# | 8      | 290         | "Subj6"   | "f" | 19.0 | 5.0    | 15442            |
# | 9      | 1187        | "Subj48"  | "f" | 20.0 | 5.0    | 18047            |
# | 10     | 422         | "Subj324" | "f" | 47.0 | 5.0    | 18922            |
# ...

# %%
size(poems)
# Out:
# (275996,31)

# %%
names(poems)
# Out:
# 31-element Array{Symbol,1}:
#  :ReadingTime
#  :Subject
#  :Sex
#  :Age
#  :NPoems
#  :MultipleChoiceRT
#  :Trial
#  :NumberOfWordsIntoLine
#  :PositionBegMidEnd
#  :SentenceLength
#  :Poem
#  :Word
#  :WordFrequencyInPoem
#  ⋮
#  :WordFormFrequency
#  :NumberOfMeanings
#  :IsFunctionWord
#  :HasPunctuationMark
#  :NumberOfMorphemes
#  :LogReadingTime
#  :LogWordFormFrequency
#  :LogLemmaFrequency
#  :LogFamilySize
#  :LogMultipleChoiceRT
#  :LogNPoems
#  :LogNumberOfMeanings

# %%
m0 = fit(lmm(Lrt ~ Fre + Mul + Age + (1|Poem)+ (1|Subject)+ (1|Word), poems))
# Out:
# key not found: :Lrt
# while loading In[4], in expression starting on line 1
#
#  in getindex at /home/juser/.julia/v0.3/DataFrames/src/other/index.jl:125
#  in getindex at /home/juser/.julia/v0.3/DataFrames/src/dataframe/dataframe.jl:206
#  in anonymous at /home/juser/.julia/v0.3/DataFrames/src/statsmodels/formula.jl:237
#  in map at ./base.jl:189
#  in ModelFrame at /home/juser/.julia/v0.3/DataFrames/src/statsmodels/formula.jl:237
#  in lmm at /home/juser/.julia/v0.3/MixedModels/src/linearmixedmodels.jl:25
